# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Daten

# %% [markdown]
# Datensatz importieren

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kirenz/daten/main/statistik/02-1-bean-data-full-x.csv', header = None, names=["beans"])

# %% [markdown]
# Datenüberblick

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   beans   915 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB

# %%
df.head()
# Out:
#    beans
# 0    219
# 1    244
# 2    260
# 3    269
# 4    273

# %% [markdown]
# # Analyse

# %%
sns.displot(data=df, x="beans");

# %%
sns.boxplot(data=df, y="beans");

# %% [markdown]
# Logarithmierte Skala

# %%
sns.displot(data=df, x="beans", log_scale=True);

# %% [markdown]
# Ohne Darstellung der Ausreißer:

# %%
sns.boxplot(data=df, y="beans",  showfliers=False);

# %% [markdown]
# ## Statistische Kennzahlen

# %%
df["beans"].describe()
# Out:
# count      915.000000
# mean      2408.745355
# std       2422.170502
# min        219.000000
# 25%       1110.000000
# 50%       1775.000000
# 75%       2599.500000
# max      31337.000000
# Name: beans, dtype: float64

# %%
df["beans"].median()
# Out:
# 1775.0

# %%
df["beans"].mode()
# Out:
# 0    10000
# dtype: int64

# %%
df["beans"].mean()
# Out:
# 2408.7453551912567

# %% [markdown]
# #### Ausreißer entfernen

# %%
df_aus = df[df['beans'] <= 15000]

# %%
df_aus["beans"].describe()
# Out:
# count      912.000000
# mean      2339.133772
# std       2074.500559
# min        219.000000
# 25%       1108.000000
# 50%       1770.000000
# 75%       2588.500000
# max      14237.000000
# Name: beans, dtype: float64

# %%
df_aus.mode()
# Out:
#    beans
# 0  10000

# %%
df_aus["beans"].median()
# Out:
# 1770.0

# %%
df_aus["beans"].mean()
# Out:
# 2339.1337719298244

# %%
sns.displot(data=df_aus, x="beans");
